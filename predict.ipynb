# %%
# %matplotlib inline

import os

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plt.rcParams['font.size'] = 6
plt.rcParams['figure.figsize'] = (6,6)

from collections import Counter

import pandas as pd
import numpy as np

from keras.models import load_model

from keras_preprocessing.image import array_to_img, img_to_array, load_img
#from scipy.misc import imresize
from cv2 import resize
import cv2
from PIL import Image

# %%
img_height, img_width, channels = 350, 350, 3

# %%
model = load_model('model.h5')

# %%
plt.rcParams['font.size'] = 6
plt.rcParams['figure.figsize'] = (3,3)

img = cv2.imread('lyx.jpg')
#plot
b, g, r = cv2.split(img)
plt.imshow(cv2.merge([r, g, b]))
img = resize(img, (img_height, img_width))
test_x = img_to_array(img).reshape(img_height, img_width, channels)
test_x = (test_x / 255.).reshape((1,) + test_x.shape)
predicted = model.predict(test_x)
print("predicted: %.5f" % predicted[0][0])
# Out:
# 2023-03-13 13:03:03.547682: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-03-13 13:03:03.755771: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 2s 2s/step
# predicted: 4.04049
